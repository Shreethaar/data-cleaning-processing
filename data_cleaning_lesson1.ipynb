# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/A232 /Data Analytics/lab/rollingsales_bronx.xlsx')

# %%
df.head()
# Out:
#   Bronx Rolling Sales.  All Sales From April 2023 - March 2024    Unnamed: 1  \
# 0  For sales prior to the Final Roll, Neighborhoo...                     NaN
# 1  Building Class Category is based on Building C...                     NaN
# 2  Note: Condominium and cooperative sales are on...                     NaN
# 3                                            BOROUGH            NEIGHBORHOOD
# 4                                                  2                BATHGATE
#
#                 Unnamed: 2            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                      NaN                   NaN        NaN        NaN
# 1                      NaN                   NaN        NaN        NaN
# 2                      NaN                   NaN        NaN        NaN
# 3  BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT      BLOCK        LOT
# 4  01 ONE FAMILY DWELLINGS                     1       3030         66
#
#   Unnamed: 6                 Unnamed: 7        Unnamed: 8        Unnamed: 9  \
# 0        NaN                        NaN               NaN               NaN
# 1        NaN                        NaN               NaN               NaN
# 2        NaN                        NaN               NaN               NaN
# 3   EASEMENT  BUILDING CLASS AT PRESENT           ADDRESS  APARTMENT NUMBER
# 4        NaN                         A1  4453 PARK AVENUE               NaN
#
#    ...        Unnamed: 11       Unnamed: 12  Unnamed: 13       Unnamed: 14  \
# 0  ...                NaN               NaN          NaN               NaN
# 1  ...                NaN               NaN          NaN               NaN
# 2  ...                NaN               NaN          NaN               NaN
# 3  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET
# 4  ...                  1                 0            1              1646
#
#          Unnamed: 15 Unnamed: 16                Unnamed: 17  \
# 0                NaN         NaN                        NaN
# 1                NaN         NaN                        NaN
# 2                NaN         NaN                        NaN
# 3  GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE
# 4               1497        1899                          1
#
#                       Unnamed: 18 PTS Sales Data as of 04/12/2024  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3  BUILDING CLASS AT TIME OF SALE                      SALE PRICE
# 4                              A1                          215000
#
#            Unnamed: 20
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3            SALE DATE
# 4  2023-04-18 00:00:00
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Bronx Rolling Sales.  All Sales From April 2023 - March 2024',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'PTS Sales Data as of 04/12/2024', 'Unnamed: 20'],
#       dtype='object')

# %%
cols = df.columns
new_cols = []
for column in cols:
    proper_cols = column.title()
    proper_cols_hyphen = proper_cols.replace(" ", "_")
    clean_col = proper_cols_hyphen.replace("-", "_")
    new_cols.append(clean_col)

new_cols
df.columns = new_cols

df.head()
# Out:
#   Bronx_Rolling_Sales.__All_Sales_From_April_2023___March_2024    Unnamed:_1  \
# 0  For sales prior to the Final Roll, Neighborhoo...                     NaN
# 1  Building Class Category is based on Building C...                     NaN
# 2  Note: Condominium and cooperative sales are on...                     NaN
# 3                                            BOROUGH            NEIGHBORHOOD
# 4                                                  2                BATHGATE
#
#                 Unnamed:_2            Unnamed:_3 Unnamed:_4 Unnamed:_5  \
# 0                      NaN                   NaN        NaN        NaN
# 1                      NaN                   NaN        NaN        NaN
# 2                      NaN                   NaN        NaN        NaN
# 3  BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT      BLOCK        LOT
# 4  01 ONE FAMILY DWELLINGS                     1       3030         66
#
#   Unnamed:_6                 Unnamed:_7        Unnamed:_8        Unnamed:_9  \
# 0        NaN                        NaN               NaN               NaN
# 1        NaN                        NaN               NaN               NaN
# 2        NaN                        NaN               NaN               NaN
# 3   EASEMENT  BUILDING CLASS AT PRESENT           ADDRESS  APARTMENT NUMBER
# 4        NaN                         A1  4453 PARK AVENUE               NaN
#
#    ...        Unnamed:_11       Unnamed:_12  Unnamed:_13       Unnamed:_14  \
# 0  ...                NaN               NaN          NaN               NaN
# 1  ...                NaN               NaN          NaN               NaN
# 2  ...                NaN               NaN          NaN               NaN
# 3  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET
# 4  ...                  1                 0            1              1646
#
#          Unnamed:_15 Unnamed:_16                Unnamed:_17  \
# 0                NaN         NaN                        NaN
# 1                NaN         NaN                        NaN
# 2                NaN         NaN                        NaN
# 3  GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE
# 4               1497        1899                          1
#
#                       Unnamed:_18 Pts_Sales_Data_As_Of_04/12/2024  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3  BUILDING CLASS AT TIME OF SALE                      SALE PRICE
# 4                              A1                          215000
#
#            Unnamed:_20
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3            SALE DATE
# 4  2023-04-18 00:00:00
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#      Bronx_Rolling_Sales.__All_Sales_From_April_2023___March_2024 Unnamed:_1  \
# 5688                                                  2             WOODLAWN
# 5689                                                  2             WOODLAWN
# 5690                                                  2             WOODLAWN
# 5691                                                  2             WOODLAWN
# 5692                                                  2             WOODLAWN
#
#                                     Unnamed:_2 Unnamed:_3 Unnamed:_4  \
# 5688            10 COOPS - ELEVATOR APARTMENTS          2       3398
# 5689            10 COOPS - ELEVATOR APARTMENTS          2       3398
# 5690            10 COOPS - ELEVATOR APARTMENTS          2       3398
# 5691                        22 STORE BUILDINGS          4       3380
# 5692  35 INDOOR PUBLIC AND CULTURAL FACILITIES          4       3380
#
#      Unnamed:_5 Unnamed:_6 Unnamed:_7               Unnamed:_8 Unnamed:_9  \
# 5688         97        NaN         D4  4295 WEBSTER AVENUE, 3I        NaN
# 5689         97        NaN         D4  4295 WEBSTER AVENUE, 5C        NaN
# 5690         97        NaN         D4  4295 WEBSTER AVENUE, 5F        NaN
# 5691         46        NaN         K1      4361 KATONAH AVENUE        NaN
# 5692         54        NaN         P8      4351 KATONAH AVENUE        NaN
#
#       ... Unnamed:_11 Unnamed:_12 Unnamed:_13 Unnamed:_14 Unnamed:_15  \
# 5688  ...         NaN         NaN         NaN         NaN         NaN
# 5689  ...         NaN         NaN         NaN         NaN         NaN
# 5690  ...         NaN         NaN         NaN         NaN         NaN
# 5691  ...           0           1           1        9699        3400
# 5692  ...           0           1           1        3121        2520
#
#      Unnamed:_16 Unnamed:_17 Unnamed:_18 Pts_Sales_Data_As_Of_04/12/2024  \
# 5688        1957           2          D4                          125000
# 5689        1957           2          D4                          135000
# 5690        1957           2          D4                          265000
# 5691        1970           4          K1                               0
# 5692        1970           4          P8                               0
#
#               Unnamed:_20
# 5688  2023-05-09 00:00:00
# 5689  2023-10-16 00:00:00
# 5690  2023-09-07 00:00:00
# 5691  2023-04-17 00:00:00
# 5692  2023-04-17 00:00:00
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# Bronx_Rolling_Sales.__All_Sales_From_April_2023___March_2024    object
# Unnamed:_1                                                      object
# Unnamed:_2                                                      object
# Unnamed:_3                                                      object
# Unnamed:_4                                                      object
# Unnamed:_5                                                      object
# Unnamed:_6                                                      object
# Unnamed:_7                                                      object
# Unnamed:_8                                                      object
# Unnamed:_9                                                      object
# Unnamed:_10                                                     object
# Unnamed:_11                                                     object
# Unnamed:_12                                                     object
# Unnamed:_13                                                     object
# Unnamed:_14                                                     object
# Unnamed:_15                                                     object
# Unnamed:_16                                                     object
# Unnamed:_17                                                     object
# Unnamed:_18                                                     object
# Pts_Sales_Data_As_Of_04/12/2024                                 object
# Unnamed:_20                                                     object
# dtype: object
